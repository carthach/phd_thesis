# %%
"""
========
Barchart
========

A bar plot with errorbars and height labels on individual bars
"""
import numpy as np
import matplotlib.pyplot as plt

#Themes
plt.style.use('seaborn')

SMALL_SIZE = 12
MEDIUM_SIZE = 14
BIGGER_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=BIGGER_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

N = 2
fitness = (0.784, 0.625)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, fitness, width)

distance = (-0.784, -0.716)

rects2 = ax.bar(ind + width, distance, width)

# add some text for labels, title and axes ticks
ax.set_ylabel('Correlation $\\rho$')
ax.set_title('', fontsize=18)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('Hamming', 'Swap'))

ax.legend((rects1[0], rects2[0]), ('Fitness', 'Distance'), loc="upper left", bbox_to_anchor=(1,1))

ax.xaxis.grid(False)

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        
#         if height > 0.0:
#             height *= 1.05
#         else:
#             height *= 1.15
        
        ax.text(rect.get_x() + rect.get_width()/2., height,
                '%.4f' % float(height),
                ha='center', va='bottom')
            

autolabel(rects1)
autolabel(rects2)

plt.ylim([-1.0,1.0])
plt.savefig("measure_bar.pdf", bbox_inches='tight', dpi=1200)
plt.show()

# %%
#FOR THE STRING REPRESENTATION

N = 2
fitness = (0.525, 0.480)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, fitness, width)

distance = (-0.852, -0.576)

rects2 = ax.bar(ind + width, distance, width)

# add some text for labels, title and axes ticks
ax.set_ylabel('Correlation $\\rho$')
ax.set_title('', fontsize=18)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('Linear', 'Parallel'))

ax.legend((rects1[0], rects2[0]), ('Fitness', 'Distance'), loc="upper left", bbox_to_anchor=(1,1))

ax.xaxis.grid(False)

def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        
#         if height > 0.0:
#             height *= 1.05
#         else:
#             height *= 1.15
        
        ax.text(rect.get_x() + rect.get_width()/2., height,
                '%.4f' % float(height),
                ha='center', va='bottom')
            

autolabel(rects1)
autolabel(rects2)

plt.ylim([-1.0,1.0])
plt.savefig("reps_bar.pdf", bbox_inches='tight', dpi=1200)
plt.show()
