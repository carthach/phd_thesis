# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import itertools
from mpl_toolkits.mplot3d import Axes3D
import os
import glob
import madmom

from essentia import *
from essentia.standard import *

# %%
filename = "samples/strings/violin_A4_05_forte_arco-normal.mp3"
audio = MonoLoader(filename=filename, sampleRate=44100)()
plt.plot(audio)
plt.show()

# %%
f, t, Sxx = signal.spectrogram(audio, 44100, nfft=512)
plt.pcolormesh(t, f, Sxx)
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
spec = madmom.audio.spectrogram.Spectrogram(filename)
specT = np.transpose(spec)
plt.plot(spec)
plt.show()

# %%
x = audio
NFFT=512
Fs = 44100
ax1 = plt.subplot(211)
plt.plot(x)
plt.subplot(212, sharex=ax1)
Pxx, freqs, bins, im = plt.specgram(x, NFFT=NFFT, Fs=Fs)
plt.show()

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
plt.subplot(211)
librosa.display.waveplot(y, x_axis='time')
plt.title('Monophonic')
plt.xlabel("")
plt.subplot(212)
D = librosa.amplitude_to_db(librosa.stft(y), ref=np.max)
librosa.display.specshow(D, x_axis='time', y_axis='log')
# plt.colorbar(format='%+2.0f dB')
plt.title('Linear-frequency power spectrogram')
plt.show()
